# %% [markdown]
# ## Customer Lifetime Value (CLV)

# %% [markdown]
# ### 1.Overview

# %% [markdown]
# Customer Lifetime Value (CLV) analysis is a crucial concept in marketing and customer relationship management. It helps businesses understand the long-term value that each customer brings to the company, enabling them to make data-driven decisions regarding customer acquisition, retention, and marketing strategies.

# %% [markdown]
# ### 2.Target

# %% [markdown]
# By analyzing customer lifetime value, you can identify the most effective marketing channels and campaigns for acquiring high-value customers. Additionally, you can develop targeted retention strategies to keep these valuable customers engaged and loyal.

# %% [markdown]
# ### 3.DataSet information:

# %% [markdown]
# For this project we will use a dataset based on customers’ relationships with the business. This DataSet is stored in File "Data".
#
# **Attribute Information:**
#
# * **customer_id:** Customer Identification.
# * **channel:** The various marketing and communication channels through which a company interacts with its customers.
# * **cost:** The costs associated with acquiring and serving to customers.
# * **conversion_rate:** Conversion rate refers to the percentage of potential customers who take a desired action, such as making a purchase, out of the total number of individuals who were exposed to a marketing campaign or visited a particular channel.
# * **revenue:** Revenue refers to the total amount of money generated from sales or customer transactions within a specific period.

# %% [markdown]
# ### 4.Import libraries

# %%
#Import main libraries:
import pandas as pd
import plotly.graph_objs as go
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly_dark"

# %% [markdown]
# ### 5.Import DataSet

# %%
#Import Dataset:
df_clv = pd.read_csv("Data/customer_acquisition_data.csv")
df_clv.sample(n=10)
# Out:
#      customer_id           channel       cost  conversion_rate  revenue
# 230          231   email marketing   5.246263         0.043822     1643
# 76            77   email marketing   5.246263         0.043822     1736
# 84            85  paid advertising  30.450327         0.016341     4312
# 415          416      social media   9.546326         0.167592      941
# 123          124          referral   8.320327         0.123145     3376
# 312          313      social media   9.546326         0.167592     2974
# 355          356      social media   9.546326         0.167592     3278
# 494          495  paid advertising  30.450327         0.016341      956
# 517          518  paid advertising  30.450327         0.016341     1397
# 320          321  paid advertising  30.450327         0.016341     1804

# %%
#Dataframe Size:
print('df_clv dimensions: ', df_clv.shape)
# Out:
# df_clv dimensions:  (800, 5)

# %% [markdown]
# **OBS**:
# * There are 5 columns (features) and 800 rows.

# %% [markdown]
# ### 6.Data Preparation:

# %%
#Check for missing values and duplicates rows:
print("Duplicate rows:\n ", df_clv.duplicated().sum())
print("Missing Values:\n" + df_clv.isnull().sum().to_string())
# Out:
# Duplicate rows:
#   0
# Missing Values:
# customer_id        0
# channel            0
# cost               0
# conversion_rate    0
# revenue            0

# %% [markdown]
# There are not any duplicated row or missing values.

# %% [markdown]
# ### 7.Data Visualization:

# %%
#Plot the distribution of acquisition cost by the customer:
fig = px.histogram(data_frame=df_clv, 
                   x="cost", 
                   nbins=20, 
                   title='Distribution of Acquisition Cost',
                   color='channel',text_auto=True)
fig.show()
# Out:
# <div>                            <div id="bce59672-3227-4430-a42e-36886b909e97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce59672-3227-4430-a42e-36886b909e97")) {                    Plotly.newPlot(                        "bce59672-3227-4430-a42e-36886b909e97",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"channel=referral<br>cost=%{x}<br>count=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"referral","nbinsx":20,"offsetgroup":"referral","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.320326732170223,8.3 ...

# %% [markdown]
# **OBS:**
#
# * The **"Referral"** and **"Email Marketing"** channels have in total the highest number of customers (around 400) with acquisition costs ranging between 8 and 9.
#
# * **"paid advertising"** has 194 customer with the highest acquisition cost (30 appoximately).
#
# * **" email marketing"** has 214 customer with the lowest acquisition cost (5 appoximately).

# %%
#Plot the revenue cost by the customer:
fig = px.histogram(data_frame=df_clv, 
                   x="revenue", 
                   nbins=50, 
                   title='Distribution of Revenue',
                   color='channel')
fig.show()
# Out:
# <div>                            <div id="cb19d257-1874-4703-a2da-9861fe9b5086" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb19d257-1874-4703-a2da-9861fe9b5086")) {                    Plotly.newPlot(                        "cb19d257-1874-4703-a2da-9861fe9b5086",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"channel=referral<br>revenue=%{x}<br>count=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"referral","nbinsx":50,"offsetgroup":"referral","orientation":"v","showlegend":true,"x":[4199,2419,1455,1147,1456,4439,3239,2021,4776,3868,832,571,3603,2390,868,2376,1361,3525,3453,3642,558,3953,3642,3115,1919,3376,1429,4615,4756,1960,3433,2949,2357,4365,3120,3886,4674,3879,1719,2216,1838,1865,1275,1054,606,620,1711,3062,3306,1121,4872,3069,4172,2980,2213,3270,4162,4933,3428,4994,4212,4632,966,2729,4923,2116,3326,2139,2322,1492,3377,1171,4155,2387,2086,3315,1979,4517,849,2219,3092,2661,3527,1608,2183,1588,4318,500,2881,1280,838,1524,1248,2245,2995,3613,3984,4951,1194,3929,4923,1451,3806,2557,1163,2424,2685,3857,1303,3809,2650,3315,3974,3667,4954,2824,4338,3639,578,2589,3722,2052,4493,3277,516,2837,983,3673,2561,4820,1850,3630,1597,3798,2759,3195,2525,1642,4882,2472,1103,2952,4080,3917,4568,3669,2128,2060,3540,1302,4603,1847,2558,3508,3831,3989,2745,2014,3982,3797,3509,1140,1899,1008,1151,1313,3525,1549,3792,1071,1992,1214,1176,1244,4332,2666,4085,1903,4164,2506,1004,2689,2857,3751,1464,2750,2362,1053,3980,1825,4237,1388,1704,3520,3708,1111,4778,970,3531,3601,4423,2970,1597,1190,3236,3620,1828],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"channel=paid advertising<br>revenue=%{x}<br>count=%{y}<extra></extra>","legendgroup":"paid advertising","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"paid advertising","nbinsx":50,"offsetgroup":"paid advertising","orientation":"v","showlegend":true,"x":[3410,3856,1303,4549,1976,4455,1385,2026,4846,3326,1004,3596,2573,2949,719,674,1806,4210,2529,2237,2807,2620,3112,4540,3308,4312,1771,1364,3809,1681,4560,2695,4134,3951,2800,2389,912,4854,1722,2357,3580,3886,4732,1268,3842,4947,1249,622,1294,2615,620,2692,3037,1357,1377,4887,3593,1361,2058,1218,1467,1303,2736,3754,3139,4469,2230,4290,1568,3847,3175,1502,1717,3040,984,4559,905,3170,3975,3780,3456,1804,3196,3903,2242,3875,2949,3822,3947,1694,2531,4779,1016,4460,534,3970,4998,1008,3252,4444,999,2152,3444,4171,4598,3273,2068,1523,533,3803,510,2648,1976,2630,1659,2244,2681,3622,4511,2112,956,1474,1206,3643,2132,849,1397,2923,2328,2490,3092,3320,4533,3032,1592,4734,4055,1758,2422,4998,3882,2826,3988,765,3385,1518,2528,2821,1576,4905,3770,2555,3500,4600,1661,2435,1491,4659,4693,2296,4085,1253,4649,4910,3436,3902,676,4171,2777,2607,4662,933,3862,2849,3036,2198,684,4289,2333,3959,4354,2384,4550,1002,3436,808,1348,4533,2007,3027,4902,4217,4947,813],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"channel=email marketing<br>revenue=%{x}<br>count=%{y}<extra></extra>","legendgroup":"email marketing","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"email marketing","nbinsx":50,"offsetgroup":"email marketing","orientation":"v","showlegend":true,"x":[3164,700,3003,3562,4004,3932,1885,4681,4342,3466,1962,2754,3472,3890,2952,1736,4586,2741,711,3280,4302,1874,2933,4947,4539,2574,3338,3326,1694,3442,3474,730,1067,2723,1272,1988,2624,1528,2486,755,3522,2506,1023,4727,2963,3803,2894,918,3309,3677,3667,2906,1220,3146,4728,3180,2510,2201,800,3602,1760,3550,1643,4504,1644,2079,4940,2490,1314,4742,1165,2176,1237,3796,4645,3397,3672,923,2749,3226,3436,4105,2164,2537,3872,3288,4956,813,4731,999,3212,3218,2297,3954,3573,36 ...

# %% [markdown]
# **OBS:**
#
# * Apparently all channels contribute the revenue equally.

# %%
# Plot compare the cost of acquisition across different channels
# Identify the most and least profitable channels
cost_by_channel = df_clv.groupby('channel')['cost'].mean().reset_index()

fig = px.bar(cost_by_channel, 
             x='channel', 
             y='cost', 
             title='Customer Acquisition Cost by Channel',
             color='channel')
fig.show()
# Out:
# <div>                            <div id="addacb34-51fd-498c-9058-f21b6232ea0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("addacb34-51fd-498c-9058-f21b6232ea0c")) {                    Plotly.newPlot(                        "addacb34-51fd-498c-9058-f21b6232ea0c",                        [{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>cost=%{y}<extra></extra>","legendgroup":"email marketing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"email marketing","offsetgroup":"email marketing","orientation":"v","showlegend":true,"textposition":"auto","x":["email marketing"],"xaxis":"x","y":[5.2462632712450965],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>cost=%{y}<extra></extra>","legendgroup":"paid advertising","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"paid advertising","offsetgroup":"paid advertising","orientation":"v","showlegend":true,"textposition":"auto","x":["paid advertising"],"xaxis":"x","y":[30.450327213520207],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>cost=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"referral","offsetgroup":"referral","orientation":"v","showlegend":true,"textposition":"auto","x":["referral"],"xaxis":"x","y":[8.320326732170223],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>cost=%{y}<extra></extra>","legendgroup":"social media","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"social media","offsetgroup":"social media","orientation":"v","showlegend":true,"textposition":"auto","x":["social media"],"xaxis":"x","y":[9.546325667652964],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"], ...

# %% [markdown]
# **OBS:**
#
# * "**paid advertisement**" is the most expensive channel.
# * "**email marketing**" is the least expensive channel.

# %%
# Plot "conversion_rate" vs "channel"
# Identify which channels are most and least effective at converting customers:
conversion_by_channel = df_clv.groupby('channel')['conversion_rate'].mean().reset_index()

fig = px.bar(conversion_by_channel, x='channel', 
             y='conversion_rate', 
             title='Conversion Rate by Channel',
             color='channel')
fig.show()
# Out:
# <div>                            <div id="fbc8d543-f506-481f-aa0f-c807628bda74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbc8d543-f506-481f-aa0f-c807628bda74")) {                    Plotly.newPlot(                        "fbc8d543-f506-481f-aa0f-c807628bda74",                        [{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>conversion_rate=%{y}<extra></extra>","legendgroup":"email marketing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"email marketing","offsetgroup":"email marketing","orientation":"v","showlegend":true,"textposition":"auto","x":["email marketing"],"xaxis":"x","y":[0.04382222859493809],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>conversion_rate=%{y}<extra></extra>","legendgroup":"paid advertising","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"paid advertising","offsetgroup":"paid advertising","orientation":"v","showlegend":true,"textposition":"auto","x":["paid advertising"],"xaxis":"x","y":[0.0163414915688768],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>conversion_rate=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"referral","offsetgroup":"referral","orientation":"v","showlegend":true,"textposition":"auto","x":["referral"],"xaxis":"x","y":[0.1231449787166301],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>conversion_rate=%{y}<extra></extra>","legendgroup":"social media","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"social media","offsetgroup":"social media","orientation":"v","showlegend":true,"textposition":"auto","x":["social media"],"xaxis":"x","y":[0.1675922473559195],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...

# %% [markdown]
# **OBS:**
#
# * "**Social media**" is the most effective channel for converting customers.
# * "**paid advertising**" is the least effective channel for converting customers.

# %%
# calculate the total revenue by channel.
# Find the most and least profitable channels in terms of generating revenue:
revenue_by_channel = df_clv.groupby('channel')['revenue'].sum().reset_index()

fig = px.pie(data_frame=revenue_by_channel, 
             values='revenue', 
             names='channel', 
             title='Total Revenue by Channel', 
             hole=0.6, 
             color='channel')

fig.show()
# Out:
# <div>                            <div id="0944cffa-c43f-4d25-afd9-b21089eb2ea5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0944cffa-c43f-4d25-afd9-b21089eb2ea5")) {                    Plotly.newPlot(                        "0944cffa-c43f-4d25-afd9-b21089eb2ea5",                        [{"customdata":[["email marketing"],["paid advertising"],["referral"],["social media"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"channel=%{customdata[0]}<br>revenue=%{value}<extra></extra>","labels":["email marketing","paid advertising","referral","social media"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa"]},"name":"","showlegend":true,"values":[604706,548396,569552,492667],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{" ...

# %% [markdown]
# **OBS:**
#
# * "**email marketing**" is the most profitable channel (27.3%) in terms of generating revenue.
# * "**social media**" is the least profitable channel (22.3%) in terms of generating revenue.
# * There is not a huge difference between the percentages of revenue generation.

# %%
# calculate the return on investment (ROI) for each channel:
# ROI = revenue / cost

df_clv['roi'] = df_clv['revenue'] / df_clv['cost']
roi_by_channel = df_clv.groupby('channel')['roi'].mean().reset_index()

fig = px.bar(roi_by_channel, 
             x='channel', 
             y='roi', 
             title='Return on Investment (ROI) by Channel',
             color='channel')
fig.show()
# Out:
# <div>                            <div id="9772cbe0-ec42-451a-a17d-a4d96ff0308e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9772cbe0-ec42-451a-a17d-a4d96ff0308e")) {                    Plotly.newPlot(                        "9772cbe0-ec42-451a-a17d-a4d96ff0308e",                        [{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>roi=%{y}<extra></extra>","legendgroup":"email marketing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"email marketing","offsetgroup":"email marketing","orientation":"v","showlegend":true,"textposition":"auto","x":["email marketing"],"xaxis":"x","y":[538.6174551038089],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>roi=%{y}<extra></extra>","legendgroup":"paid advertising","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"paid advertising","offsetgroup":"paid advertising","orientation":"v","showlegend":true,"textposition":"auto","x":["paid advertising"],"xaxis":"x","y":[92.83261507612053],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>roi=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"referral","offsetgroup":"referral","orientation":"v","showlegend":true,"textposition":"auto","x":["referral"],"xaxis":"x","y":[330.6912127091906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>roi=%{y}<extra></extra>","legendgroup":"social media","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"social media","offsetgroup":"social media","orientation":"v","showlegend":true,"textposition":"auto","x":["social media"],"xaxis":"x","y":[278.96228953182145],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88 ...

# %% [markdown]
# **OBS:**
#
# * The ROI from **email marketing** is higher than all other channels.
# * The ROI from **paid advertising** is the lowest.

# %% [markdown]
# ### 8.Customer Lifetime Value (CLV):

# %% [markdown]
# Calculate the customer lifetime value from each channel with the following formula:
#
# $$
# CLV = (revenue - cost) * \frac{{conversion_-rate}}{cost}
# $$

# %%
# customer lifetime Value:

df_clv['clv'] = (df_clv['revenue'] - df_clv['cost']) * df_clv['conversion_rate'] / df_clv['cost']

channel_clv = df_clv.groupby('channel')['clv'].mean().reset_index()

fig = px.bar(channel_clv, x='channel', y='clv', color='channel',
             title='Customer Lifetime Value by Channel')

fig.update_xaxes(title='Channel')
fig.update_yaxes(title='CLV')

fig.show()
# Out:
# <div>                            <div id="cb2ab395-4d63-4040-9f90-f345cd106b83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb2ab395-4d63-4040-9f90-f345cd106b83")) {                    Plotly.newPlot(                        "cb2ab395-4d63-4040-9f90-f345cd106b83",                        [{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>clv=%{y}<extra></extra>","legendgroup":"email marketing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"email marketing","offsetgroup":"email marketing","orientation":"v","showlegend":true,"textposition":"auto","x":["email marketing"],"xaxis":"x","y":[23.55959501418798],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>clv=%{y}<extra></extra>","legendgroup":"paid advertising","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"paid advertising","offsetgroup":"paid advertising","orientation":"v","showlegend":true,"textposition":"auto","x":["paid advertising"],"xaxis":"x","y":[1.5006819050143323],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>clv=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"referral","offsetgroup":"referral","orientation":"v","showlegend":true,"textposition":"auto","x":["referral"],"xaxis":"x","y":[40.59981737213324],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>clv=%{y}<extra></extra>","legendgroup":"social media","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"social media","offsetgroup":"social media","orientation":"v","showlegend":true,"textposition":"auto","x":["social media"],"xaxis":"x","y":[46.584324782834734],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8 ...

# %% [markdown]
# **OBS:**
# * "**Social Media**" and "**referral**" channels have the highest CLV.
# * "**Paid Advertising**" has the lowest CLV.

# %%
#Compare the CLV distribution of "social media" and "referral" channels:

subset = df_clv.loc[df_clv['channel'].isin(['social media', 'referral'])]

fig = px.box(data_frame=subset, 
             x='channel', 
             y='clv', 
             title='CLV Distribution by Channel',
             color='channel',
             color_discrete_map={'referral': '#00CC96', 'social media': '#AB63FA'})

fig.update_xaxes(title='Channel')
fig.update_yaxes(title='CLV')
fig.update_layout(legend_title='Channel')

fig.show()
# Out:
# <div>                            <div id="5f9d150e-55a8-42c8-a690-959230843ebd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f9d150e-55a8-42c8-a690-959230843ebd")) {                    Plotly.newPlot(                        "5f9d150e-55a8-42c8-a690-959230843ebd",                        [{"alignmentgroup":"True","hovertemplate":"channel=%{x}<br>clv=%{y}<extra></extra>","legendgroup":"referral","marker":{"color":"#00CC96"},"name":"referral","notched":false,"offsetgroup":"referral","orientation":"v","showlegend":true,"x":["referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral","referral"],"x0":" ","xaxis":"x","y":[62.0241459001184,35.679259554720375,21.411579533954235,16.853026166323566,21.42638003190109,65.57626540736308,47.81566787113969,29.78866137187294,70.56403321545248,57.12518107971012,12.190869313064924,8.327939348936336,53.20304912379412,35.25004511426164,12.723687239151628,35.0428381430057,20.02033272695007,52.048610283939595,50.982974431766195,53.78026854372138,8.13553287562725,58.383223405192616,53.78026854372138,45.980406125729935,28.27901058129395,49.843336089858525,21.026766587336066,68.18115304600917,70.26802325651543,28.88583099711492,50.68696447282914,43.52352346655237,34.76162868201549,64.48102855929598,46.054408615464205,57.39159004275347,69.0543824248735,57.28798655712551,25.318910991923385,32.67475847150924,27.080170247598872,27.4797836921639,18.747489903520727,15.476579857266254,8.845956777076186,9.053163748332125,25.200507008348563,45.19597973454674,48.80730123357883,16.468213219705394,71.984881018350 ...

# %% [markdown]
# **OBS:**
# * The Customer Lifetime Value from the "Social Media" channel is slightly better than the "referral" channel.

# %% [markdown]
# ### 9.Final Observations:

# %% [markdown]
# 1. **Reduce investment in "paid advertising"**: Since it is the most expensive channel and has the lowest Return on Investment (ROI), it may be beneficial to reconsider the allocation of resources to this channel. By reducing investment in paid advertising, you can potentially allocate those resources to other channels with higher effectiveness and ROI.
#
# 2. **Increase investment in "social media"**: As mentioned, "social media" is identified as the most effective channel and has the highest Customer Lifetime Value (CLV). This suggests that allocating more resources and investment into social media marketing efforts could yield better results and contribute to the overall success of the business.
#
# 3. **Increase investment in "referral"**: The "referral" channel is highlighted as having the highest Customer Lifetime Value (CLV). This indicates that customer referrals can be a valuable source of new customers and revenue. Increasing investment in referral programs or strategies to encourage and incentivize customer referrals can be beneficial for long-term customer acquisition and retention.
#
# 4. By focusing on channels with **higher effectiveness**, **lower costs**, and **higher CLV**, you can optimize your marketing strategies and maximize the return on your marketing investments.
